# %% [markdown]
# # Start coding and Enjoy the journey

# %% [markdown]
# ## Install the repo

# %%
# !git clone --recursive https://github.com/StayLode/Visual-Place-Recognition-Project.git

# %%
# mount google drive
from google.colab import drive
drive.mount('/content/drive')
# path to save model weights
PATH = '/content/drive/MyDrive/Colab Notebooks/Advanced ML/model_weights'

# remove previous model weights folder if exists
# %cd Visual-Place-Recognition-Project/image-matching-models/matching/third_party/SphereGlue
# !rm -rf model_weights

# copy model weights from google drive
# !cp -r "$PATH" .

# %% [markdown]
# ## Install dependencies

# %%
# %cd /content/Visual-Place-Recognition-Project/image-matching-models
# !pip install -e .[all]

# %%
# !pip install faiss-cpu

# %% [markdown]
# ## Download Datasets

# %%
# %cd /content/Visual-Place-Recognition-Project/
# !python download_datasets.py

# %% [markdown]
# ## VPR Evalutation
