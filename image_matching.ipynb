# %% [markdown]
# # Start coding and Enjoy the journey

# %% [markdown]
# ## Install the repo

# %%
# !git clone --recursive https://github.com/StayLode/Visual-Place-Recognition-Project.git

# %% [markdown]
# ## Install dependencies

# %%
# %cd /content/Visual-Place-Recognition-Project/image-matching-models
# !pip install -e .[all]

# %%
# !pip install faiss-cpu

# %% [markdown]
# ## Download Datasets

# %%
# %cd /content/Visual-Place-Recognition-Project/
# !python download_datasets.py

# %% [markdown]
# ## Full pipeline
# ### 1. VPR Evalutation
# ### 2. Run Image Matching on Retrieval Results
# ### 3. Check Re-ranking Performance

# %% [markdown]
# ### Tokyo-XS

# %%
# Run the full pipeline on the Tokyo-XS dataset
# !python run_pipeline.py \
--dataset 'tokyo_xs'

# %% [markdown]
# ### SF-XS

# %%
# Run the full pipeline on the SF-XS dataset
# !python run_pipeline.py \
--dataset 'sf_xs'

# %% [markdown]
# ### SVOX

# %%
# Run the full pipeline on the svox dataset
# !python run_pipeline.py \
--dataset 'svox'

# %% [markdown]
# ### SVOX - Sun

# %%
# Run the full pipeline on the svox (sun) dataset
# !python run_pipeline.py \
--dataset 'svox_sun'

# %% [markdown]
# ### SVOC - Night

# %%
# Run the full pipeline on the svox (sun) dataset
# !python run_pipeline.py \
--dataset 'svox_night'
