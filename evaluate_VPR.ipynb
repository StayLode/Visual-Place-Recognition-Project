# %% [markdown]
# # Start coding and Enjoy the journey

# %% [markdown]
# ## Install the repo

# %%
# !git clone --recursive https://github.com/StayLode/Visual-Place-Recognition-Project.git

# %% [markdown]
# ## Install dependencies

# %%
# %cd /content/Visual-Place-Recognition-Project/image-matching-models
# !pip install -e .[all]

# %%
# !pip install faiss-cpu

# %% [markdown]
# ## Download Datasets

# %%
# %cd /content/Visual-Place-Recognition-Project/
# !python download_datasets.py

# %% [markdown]
# ## VPR Evalutation

# %% [markdown]
# ### Tokyo-XS

# %%
# NetVlad - VGG16 - L2
# !python VPR-methods-evaluation/main.py \
--num_workers 8 \
--batch_size 32 \
--log_dir netvlad_VGG16_tokyo_xs_L2 \
--method=netvlad --backbone=VGG16 --descriptors_dimension=4096 \
--image_size 512 512 \
--database_folder data/tokyo_xs/test/database \
--queries_folder data/tokyo_xs/test/queries \
--distance L2 \
--num_preds_to_save 20 \
--recall_values 1 5 10 20 \
--save_for_uncertainty

# %%
# NetVlad - VGG16 - dot
# !python VPR-methods-evaluation/main.py \
--num_workers 8 \
--batch_size 32 \
--log_dir netvlad_VGG16_tokyo_xs_dot \
--method=netvlad --backbone=VGG16 --descriptors_dimension=4096 \
--image_size 512 512 \
--database_folder data/tokyo_xs/test/database \
--queries_folder data/tokyo_xs/test/queries \
--distance dot \
--num_preds_to_save 20 \
--recall_values 1 5 10 20 \
--save_for_uncertainty

# %%
# MixVPR- Resnet50 - L2
# !python VPR-methods-evaluation/main.py \
--num_workers 8 \
--batch_size 32 \
--log_dir mixvpr_resnet50_tokyo_xs_L2 \
--method=mixvpr --backbone=ResNet50 --descriptors_dimension=4096 \
--image_size 512 512 \
--database_folder data/tokyo_xs/test/database \
--queries_folder data/tokyo_xs/test/queries \
--distance L2 \
--num_preds_to_save 20 \
--recall_values 1 5 10 20 \
--save_for_uncertainty

# %%
# MixVPR- Resnet50 - dot
# !python VPR-methods-evaluation/main.py \
--num_workers 8 \
--batch_size 32 \
--log_dir mixvpr_resnet50_tokyo_xs_dot \
--method=mixvpr --backbone=ResNet50 --descriptors_dimension=4096 \
--image_size 512 512 \
--database_folder data/tokyo_xs/test/database \
--queries_folder data/tokyo_xs/test/queries \
--distance dot \
--num_preds_to_save 20 \
--recall_values 1 5 10 20 \
--save_for_uncertainty

# %%
# Megaloc - Dinov2 - L2
# !python VPR-methods-evaluation/main.py \
--num_workers 8 \
--batch_size 32 \
--log_dir megaloc_dinov2_tokyo_xs_L2 \
--method=megaloc --backbone=Dinov2 --descriptors_dimension=8448 \
--image_size 512 512 \
--database_folder data/tokyo_xs/test/database \
--queries_folder data/tokyo_xs/test/queries \
--distance L2 \
--num_preds_to_save 20 \
--recall_values 1 5 10 20 \
--save_for_uncertainty

# %%
# Megaloc - Dinov2 - dot
# !python VPR-methods-evaluation/main.py \
--num_workers 8 \
--batch_size 32 \
--log_dir megaloc_dinov2_tokyo_xs_dot \
--method=megaloc --backbone=Dinov2 --descriptors_dimension=8448 \
--image_size 512 512 \
--database_folder data/tokyo_xs/test/database \
--queries_folder data/tokyo_xs/test/queries \
--distance dot \
--num_preds_to_save 20 \
--recall_values 1 5 10 20 \
--save_for_uncertainty

# %%
# CosPlace - ResNet50 - L2
# !python VPR-methods-evaluation/main.py \
--num_workers 8 \
--batch_size 32 \
--log_dir cosplace_resnet50_tokyo_xs_L2 \
--method=cosplace --backbone=ResNet50 --descriptors_dimension=2048 \
--image_size 512 512 \
--database_folder data/tokyo_xs/test/database \
--queries_folder data/tokyo_xs/test/queries \
--distance L2 \
--num_preds_to_save 20 \
--recall_values 1 5 10 20 \
--save_for_uncertainty

# %%
# CosPlace - ResNet50 - dot
# !python VPR-methods-evaluation/main.py \
--num_workers 8 \
--batch_size 32 \
--log_dir cosplace_resnet50_tokyo_xs_dot \
--method=cosplace --backbone=ResNet50 --descriptors_dimension=2048 \
--image_size 512 512 \
--database_folder data/tokyo_xs/test/database \
--queries_folder data/tokyo_xs/test/queries \
--distance dot \
--num_preds_to_save 20 \
--recall_values 1 5 10 20 \
--save_for_uncertainty

# %% [markdown]
# ### SF-XS

# %%
# NetVlad - VGG16 - L2
# !python VPR-methods-evaluation/main.py \
--num_workers 8 \
--batch_size 32 \
--log_dir netvlad_VGG16_sf_xs_test_L2 \
--method=netvlad --backbone=VGG16 --descriptors_dimension=4096 \
--image_size 512 512 \
--database_folder data/sf_xs/test/database \
--queries_folder data/sf_xs/test/queries \
--distance L2 \
--num_preds_to_save 20 \
--recall_values 1 5 10 20 \
--save_for_uncertainty

# %%
# NetVlad - VGG16 - dot
# !python VPR-methods-evaluation/main.py \
--num_workers 8 \
--batch_size 32 \
--log_dir netvlad_VGG16_sf_xs_test_dot \
--method=netvlad --backbone=VGG16 --descriptors_dimension=4096 \
--image_size 512 512 \
--database_folder data/sf_xs/test/database \
--queries_folder data/sf_xs/test/queries \
--distance dot \
--num_preds_to_save 20 \
--recall_values 1 5 10 20 \
--save_for_uncertainty

# %%
# MixVPR- Resnet50 - L2
# !python VPR-methods-evaluation/main.py \
--num_workers 8 \
--batch_size 32 \
--log_dir mixvpr_resnet50_sf_xs_test_L2 \
--method=mixvpr --backbone=ResNet50 --descriptors_dimension=4096 \
--image_size 512 512 \
--database_folder data/sf_xs/test/database \
--queries_folder data/sf_xs/test/queries \
--distance L2 \
--num_preds_to_save 20 \
--recall_values 1 5 10 20 \
--save_for_uncertainty

# %%
# MixVPR- Resnet50 - dot
# !python VPR-methods-evaluation/main.py \
--num_workers 8 \
--batch_size 32 \
--log_dir mixvpr_resnet50_sf_xs_test_dot \
--method=mixvpr --backbone=ResNet50 --descriptors_dimension=4096 \
--image_size 512 512 \
--database_folder data/sf_xs/test/database \
--queries_folder data/sf_xs/test/queries \
--distance dot \
--num_preds_to_save 20 \
--recall_values 1 5 10 20 \
--save_for_uncertainty

# %%
# Megaloc - Dinov2 - L2
# !python VPR-methods-evaluation/main.py \
--num_workers 8 \
--batch_size 32 \
--log_dir megaloc_dinov2_sf_xs_test_L2 \
--method=megaloc --backbone=Dinov2 --descriptors_dimension=8448 \
--image_size 512 512 \
--database_folder data/sf_xs/test/database \
--queries_folder data/sf_xs/test/queries \
--distance L2 \
--num_preds_to_save 20 \
--recall_values 1 5 10 20 \
--save_for_uncertainty

# %%
# Megaloc - Dinov2 - dot
# !python VPR-methods-evaluation/main.py \
--num_workers 8 \
--batch_size 32 \
--log_dir megaloc_dinov2_sf_xs_test_dot \
--method=megaloc --backbone=Dinov2 --descriptors_dimension=8448 \
--image_size 512 512 \
--database_folder data/sf_xs/test/database \
--queries_folder data/sf_xs/test/queries \
--distance dot \
--num_preds_to_save 20 \
--recall_values 1 5 10 20 \
--save_for_uncertainty

# %%
# CosPlace - ResNet50 - L2
# !python VPR-methods-evaluation/main.py \
--num_workers 8 \
--batch_size 32 \
--log_dir cosplace_resnet50_sf_xs_test_L2 \
--method=cosplace --backbone=ResNet50 --descriptors_dimension=2048 \
--image_size 512 512 \
--database_folder data/sf_xs/test/database \
--queries_folder data/sf_xs/test/queries \
--distance L2 \
--num_preds_to_save 20 \
--recall_values 1 5 10 20 \
--save_for_uncertainty

# %%
# CosPlace - ResNet50 - dot
# !python VPR-methods-evaluation/main.py \
--num_workers 8 \
--batch_size 32 \
--log_dir cosplace_resnet50_sf_xs_test_test_dot \
--method=cosplace --backbone=ResNet50 --descriptors_dimension=2048 \
--image_size 512 512 \
--database_folder data/sf_xs/test/database \
--queries_folder data/sf_xs/test/queries \
--distance dot \
--num_preds_to_save 20 \
--recall_values 1 5 10 20 \
--save_for_uncertainty

# %% [markdown]
# ### SVOX

# %%
# NetVlad - VGG16 - L2
# !python VPR-methods-evaluation/main.py \
--num_workers 8 \
--batch_size 32 \
--log_dir netvlad_VGG16_svox_test_L2 \
--method=netvlad --backbone=VGG16 --descriptors_dimension=4096 \
--image_size 512 512 \
--database_folder data/svox/images/test/gallery \
--queries_folder data/svox/images/test/queries_sun \
--distance L2 \
--num_preds_to_save 20 \
--recall_values 1 5 10 20 \
--save_for_uncertainty

# %%
# NetVlad - VGG16 - dot
# !python VPR-methods-evaluation/main.py \
--num_workers 8 \
--batch_size 32 \
--log_dir netvlad_VGG16_svox_test_dot \
--method=netvlad --backbone=VGG16 --descriptors_dimension=4096 \
--image_size 512 512 \
--database_folder data/svox/images/test/gallery \
--queries_folder data/svox/images/test/queries_sun \
--distance dot \
--num_preds_to_save 20 \
--recall_values 1 5 10 20 \
--save_for_uncertainty

# %%
# MixVPR- Resnet50 - L2
# !python VPR-methods-evaluation/main.py \
--num_workers 8 \
--batch_size 32 \
--log_dir mixvpr_resnet50_svox_test_L2 \
--method=mixvpr --backbone=ResNet50 --descriptors_dimension=4096 \
--image_size 512 512 \
--database_folder data/svox/images/test/gallery \
--queries_folder data/svox/images/test/queries_sun \
--distance L2 \
--num_preds_to_save 20 \
--recall_values 1 5 10 20 \
--save_for_uncertainty

# %%
# MixVPR- Resnet50 - dot
# !python VPR-methods-evaluation/main.py \
--num_workers 8 \
--batch_size 32 \
--log_dir mixvpr_resnet50_svox_test_dot \
--method=mixvpr --backbone=ResNet50 --descriptors_dimension=4096 \
--image_size 512 512 \
--database_folder data/svox/images/test/gallery \
--queries_folder data/svox/images/test/queries_sun \
--distance dot \
--num_preds_to_save 20 \
--recall_values 1 5 10 20 \
--save_for_uncertainty

# %%
# Megaloc - Dinov2 - L2
# !python VPR-methods-evaluation/main.py \
--num_workers 8 \
--batch_size 32 \
--log_dir megaloc_dinov2_svox_test_L2 \
--method=megaloc --backbone=Dinov2 --descriptors_dimension=8448 \
--image_size 512 512 \
--database_folder data/svox/images/test/gallery \
--queries_folder data/svox/images/test/queries_sun \
--distance L2 \
--num_preds_to_save 20 \
--recall_values 1 5 10 20 \
--save_for_uncertainty

# %%
# Megaloc - Dinov2 - dot
# !python VPR-methods-evaluation/main.py \
--num_workers 8 \
--batch_size 32 \
--log_dir megaloc_dinov2_svox_test_dot \
--method=megaloc --backbone=Dinov2 --descriptors_dimension=8448 \
--image_size 512 512 \
--database_folder data/svox/images/test/gallery \
--queries_folder data/svox/images/test/queries_sun \
--distance dot \
--num_preds_to_save 20 \
--recall_values 1 5 10 20 \
--save_for_uncertainty

# %%
# CosPlace - ResNet50 - L2
# !python VPR-methods-evaluation/main.py \
--num_workers 8 \
--batch_size 32 \
--log_dir cosplace_resnet50_svox_test_L2 \
--method=cosplace --backbone=ResNet50 --descriptors_dimension=2048 \
--image_size 512 512 \
--database_folder data/svox/images/test/gallery \
--queries_folder data/svox/images/test/queries_sun \
--distance L2 \
--num_preds_to_save 20 \
--recall_values 1 5 10 20 \
--save_for_uncertainty

# %%
# CosPlace - ResNet50 - dot
# !python VPR-methods-evaluation/main.py \
--num_workers 8 \
--batch_size 32 \
--log_dir cosplace_resnet50_svox_test_dot \
--method=cosplace --backbone=ResNet50 --descriptors_dimension=2048 \
--image_size 512 512 \
--database_folder data/svox/images/test/gallery \
--queries_folder data/svox/images/test/queries_sun \
--distance dot \
--num_preds_to_save 20 \
--recall_values 1 5 10 20 \
--save_for_uncertainty
